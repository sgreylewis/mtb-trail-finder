# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
colorado_df = pd.read_json('/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/CO_trails.json', orient = 'records')
alabama_df = pd.read_json('/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/Alabama_trails.json', orient = 'records')
alaska_df = pd.read_json('/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/Alaska_trails.json', orient = 'records')

# %%
alabama_df.shape
# Out:
# (500, 23)

# %%
alaska_df.shape
# Out:
# (27, 23)

# %%
colorado_df.shape
# Out:
# (500, 23)

# %%
for row in range(alabama_df.shape[0]):
    print (alabama_df.iloc[row])
# Out:
# ascent                                                           1422
# conditionDate                                     2017-11-11 18:42:27
# conditionDetails    Mostly Dry - $5 per adult, park maps available...
# conditionStatus                                             All Clear
# descent                                                         -1422
# difficulty                                                  blueBlack
# high                                                              511
# id                                                              99190
# imgMedium           https://cdn-files.apstatic.com/mtb/112642_medi...
# imgSmall            https://cdn-files.apstatic.com/mtb/112642_smal...
# imgSmallMed         https://cdn-files.apstatic.com/mtb/112642_smal...
# imgSqSmall          https://cdn-files.apstatic.com/mtb/112642_sqsm...
# latitude                                                      33.3232
# ...

# %%
alabama_df.columns
# Out:
# Index(['ascent', 'conditionDate', 'conditionDetails', 'conditionStatus',
#        'descent', 'difficulty', 'high', 'id', 'imgMedium', 'imgSmall',
#        'imgSmallMed', 'imgSqSmall', 'latitude', 'length', 'location',
#        'longitude', 'low', 'name', 'starVotes', 'stars', 'summary', 'type',
#        'url'],
#       dtype='object')

# %%
alabama_locations = list(alabama_df['location'])
alabama_locations
# Out:
# ['Indian Springs Village, Alabama',
#  'Bynum, Alabama',
#  'Holly Springs, Georgia',
#  'Dahlonega, Georgia',
#  'Auburn, Alabama',
#  'Auburn, Alabama',
#  'West End-Cobb Town, Alabama',
#  'Taylor, Alabama',
#  'Gadsden, Alabama',
#  'Lake View, Alabama',
#  'Ensley, Florida',
#  'Cumming, Georgia',
#  'Huntsville, Alabama',
#  'Roswell, Georgia',
#  'Acworth, Georgia',
#  'Louisville, Mississippi',
#  'Louisville, Mississippi',
#  'Mignon, Alabama',
#  'Chattahoochee Hills, Georgia',
#  'Cumming, Georgia',
#  'Emerson, Georgia',
#  'Tillmans Corner, Alabama',
#  'Ellijay, Georgia',
#  'Northport, Alabama',
#  'Ackerman, Mississippi',
#  'Ellijay, Georgia',
#  'Huntsville, Alabama',
#  'Villa Rica, Georgia',
#  'Columbus, Georgia',
#  'Brookside, Alabama',
#  'Dahlonega, Georgia',
#  'Huntsville, Alabama',
#  'Fort Payne, Alabama',
#  'Redstone Arsenal, Alabama',
#  'Tuskegee, Alabama',
#  'Guntersville, Alabama',
#  'Point Baker, Florida',
#  'Huntsville, Alabama',
# ...

# %%
test = 'Indian Springs Village, Alabama'
test[-7:]
# Out:
# 'Alabama'

# %%
Alabama_trails = 0
for location in alabama_locations:
    if location[-7:].lower() == 'alabama':
        Alabama_trails += 1
Alabama_trails
# Out:
# 228

# %%
alabama_df.columns
# Out:
# Index(['ascent', 'conditionDate', 'conditionDetails', 'conditionStatus',
#        'descent', 'difficulty', 'high', 'id', 'imgMedium', 'imgSmall',
#        'imgSmallMed', 'imgSqSmall', 'latitude', 'length', 'location',
#        'longitude', 'low', 'name', 'starVotes', 'stars', 'summary', 'type',
#        'url'],
#       dtype='object')

# %%
alabama_df['type'].unique()
# Out:
# array(['Featured Ride', 'Trail', 'Connector'], dtype=object)

# %%
featured = 0
for row in range(alabama_df.shape[0]):
    x = alabama_df.iloc[row]['location'][-7:].lower()
    y = alabama_df.iloc[row]['type'].lower()
    if x == 'alabama' and y == 'featured ride':
        featured += 1
featured
# Out:
# 33

# %%
AL_lat_min = alabama_df['latitude'].min()

# %%
AL_lat_max = alabama_df['latitude'].max()

# %%
lat_distance = AL_lat_max - AL_lat_min
lat_distance
# Out:
# 4.5061

# %%
AL_lon_min = alabama_df['longitude'].min()
AL_lon_max = alabama_df['longitude'].max()

# %%
lon_distance = AL_lon_max - AL_lon_min
lon_distance
# Out:
# 5.6585999999999927

# %%
AK_lat_min = alaska_df['latitude'].min()
AK_lat_max = alaska_df['latitude'].max()

# %%
AK_lat_distance = AK_lat_max - AK_lat_min
AK_lat_distance
# Out:
# 2.0305999999999997

# %%
AK_lon_min = alaska_df['longitude'].min()
AK_lon_max = alaska_df['longitude'].max()
AK_lon_distance = AK_lon_max - AK_lon_min
AK_lon_distance
# Out:
# 3.6732999999999834

# %%
#data1 = json.load('/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/CO_Central_Rockies_Almont.json')['trails']

# %%
CO_dataframes = []
files = ['/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/CO_Central_Rockies_Almont.json', 
         '/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/CO_Eastern_Plains_Campo.json',
         '/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/CO_Front_Range_Arvada.json',
         '/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/CO_Northwest_Rockies_Craig.json',
         '/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/CO_San_Luis_Valley_Del_Norte.json',
         '/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/CO_Southwest_Rockies_Cortez.json',
         '/Users/sarahlewis/Desktop/galvanize/Capstone_Project/MTB/CO_Western_Colorado_Fruita.json']
for fle in files:
    with open(fle) as json_file:  
        data = json.load(json_file)['trails']
        df = pd.DataFrame(data)
        CO_dataframes.append(df)

# %%
CO_data = pd.concat(CO_dataframes)

# %%
CO_data.shape
# Out:
# (3500, 23)

# %%
CO_trails = CO_data[CO_data['location']=='Colorado']
# Out:
# /Users/sarahlewis/ENTER/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-81-f2de13186b45> in <module>()
# ----> 1 CO_trails = CO_data[CO_data['location'][-8:]=='Colorado']
#
# ~/ENTER/envs/py3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/ENTER/envs/py3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
# ...

# %%
CO_trails.shape
# Out:
# (0, 23)

# %%
CO_data.shape
# Out:
# (3500, 23)

# %%
CO_data['location']
# Out:
# 0                        Moab, Utah
# 1                    Pine, Colorado
# 2               Whitepine, Colorado
# 3                  Cortez, Colorado
# 4                        Moab, Utah
# 5                    Pine, Colorado
# 6           Crested Butte, Colorado
# 7                        Moab, Utah
# 8                    Loma, Colorado
# 9                        Moab, Utah
# 10                       Moab, Utah
# 11                Boulder, Colorado
# 12          Idaho Springs, Colorado
# 13               Gunnison, Colorado
# 14                 Golden, Colorado
# 15     West Pleasant View, Colorado
# 16                Genesee, Colorado
# 17                  Lyons, Colorado
# 18                   Pine, Colorado
# 19                 Fruita, Colorado
# 20              Jefferson, Colorado
# 21                   Pine, Colorado
# 22                 Frisco, Colorado
# 23                 Golden, Colorado
# 24      Air Force Academy, Colorado
# 25               Morrison, Colorado
# ...

# %%
test = 'Pine, Colorado'
city_state = test.split()
city_state[1].lower()
# Out:
# 'colorado'

# %%
CO_data.columns
# Out:
# Index(['ascent', 'conditionDate', 'conditionDetails', 'conditionStatus',
#        'descent', 'difficulty', 'high', 'id', 'imgMedium', 'imgSmall',
#        'imgSmallMed', 'imgSqSmall', 'latitude', 'length', 'location',
#        'longitude', 'low', 'name', 'starVotes', 'stars', 'summary', 'type',
#        'url'],
#       dtype='object')

# %%
CO_locations = list(CO_data['location'])

# %%
Colorado_trails = 0
for location in CO_locations:
    if location[-8:].lower() == 'colorado':
        Colorado_trails += 1
Colorado_trails
# Out:
# 2920

# %%
len(CO_data['id'].unique())
# Out:
# 1253

# %%
CO_data.drop_duplicates(inplace = True)

# %%
CO_data.shape
# Out:
# (1254, 23)
