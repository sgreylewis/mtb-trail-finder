# %%
import pandas as pd
import numpy as np
from geopy.geocoders import GoogleV3, Nominatim
from geopy.distance import vincenty, great_circle
import math

# %%
US_trails = pd.read_csv('../US_trails_engineered.csv')

# %%
US_trails.shape
# Out:
# (20691, 18)

# %%
US_trails.columns
# Out:
# Index(['name', 'location', 'difficulty', 'length', 'ascent', 'descent',
#        'stars', 'latitude', 'longitude', 'summary', 'url',
#        'difficulty_encoded', 'category', 'type_Featured Ride', 'type_Trail',
#        'city/town', 'state', 'length_range'],
#       dtype='object')

# %%
US_trails.index
# Out:
# RangeIndex(start=0, stop=20691, step=1)

# %%
geolocator = GoogleV3()

# %%
#location = geolocator.geocode("1182 Shepherds Lane NE")
location = geolocator.geocode("2044 South Huron Street Denver")
#location = geolocator.geocode('University of Colorado')
#location = geolocator.geocode('Iowa City, Iowa')
location.address
# Out:
# '2044 S Huron St, Denver, CO 80223, USA'

# %%
lat_lon = (location.latitude, location.longitude)
lat_lon
# Out:
# (39.6795193, -104.9969322)

# %%
# Distances are measured in miles.
# Longitudes and latitudes are measured in degrees.
# Earth is assumed to be perfectly spherical.

earth_radius = 3960.0
degrees_to_radians = math.pi/180.0
radians_to_degrees = 180.0/math.pi

def change_in_latitude(miles):
    "Given a distance north, return the change in latitude."
    return (miles/earth_radius)*radians_to_degrees

def change_in_longitude(latitude, miles):
    "Given a latitude and a distance west, return the change in longitude."
    # Find the radius of a circle around the earth at given latitude.
    r = earth_radius*math.cos(latitude*degrees_to_radians)
    return (miles/r)*radians_to_degrees

# %%
#I want to drive 15 miles north, or 15 miles west
m = 15
lat_diff = change_in_latitude(m)
lat_diff
# Out:
# 0.21702946785258456

# %%
lon_diff = change_in_longitude(lat_lon[0], m)
lon_diff
# Out:
# 0.2819927468892867

# %%
#make a function that takes in a location, a desired crow fly distance radius, and turns it into a lat/lon difference
#add/subtract that distance in lat/long from where they are to get intervals of lat/lon within to return all the trails
#that are in that interval range
#maybe return a column with the number of miles in a crow's distance(have a disclaimer about the range of miles
#this could be driving)

# %%
lat_min = lat_lon[0] - lat_diff
lat_min
# Out:
# 39.46248983214742

# %%
lat_max = lat_lon[0] + lat_diff
lat_max
# Out:
# 39.896548767852586

# %%
lon_min = lat_lon[1] - lon_diff
lon_min
# Out:
# -105.27892494688929

# %%
lon_max = lat_lon[1] + lon_diff
lon_max
# Out:
# -104.71493945311072

# %%
lat_range = (lat_min, lat_max)
lat_range
# Out:
# (39.46248983214742, 39.896548767852586)

# %%
lon_range = (lon_min, lon_max)
lon_range
# Out:
# (-105.27892494688929, -104.71493945311072)

# %%
df = US_trails[(US_trails['latitude'] >= lat_range[0]) & (US_trails['latitude'] <= lat_range[1])] #and 
df.shape
# Out:
# (866, 18)

# %%
df.index
# Out:
# Int64Index([ 9933, 10081, 10082, 10083, 10086, 10087, 10089, 10094, 10098,
#             10105,
#             ...
#             16596, 16597, 16610, 16638, 16750, 16751, 16753, 16754, 16755,
#             16757],
#            dtype='int64', length=866)

# %%
df = df[(df['longitude'] >= lon_range[0]) & (df['longitude'] <= lon_range[1])]
df.shape
# Out:
# (112, 18)

# %%
df.index
# Out:
# Int64Index([10472, 10479, 10482, 10497, 10500, 10502, 10504, 10505, 10507,
#             10511,
#             ...
#             11510, 11511, 11513, 11514, 15684, 16547, 16580, 16594, 16596,
#             16610],
#            dtype='int64', length=112)

# %%
df.columns
# Out:
# Index(['name', 'location', 'difficulty', 'length', 'ascent', 'descent',
#        'stars', 'latitude', 'longitude', 'summary', 'url',
#        'difficulty_encoded', 'category', 'type_Featured Ride', 'type_Trail',
#        'city/town', 'state', 'length_range'],
#       dtype='object')

# %%
df['latitude'].min()
# Out:
# 39.489800000000002

# %%
df['latitude'].max()
# Out:
# 39.887900000000002

# %%
df['longitude'].min()
# Out:
# -105.2764

# %%
df['longitude'].max()
# Out:
# -104.82170000000001

# %%
df['name']
# Out:
# 10472               Lair O' the Bear - Bear Creek Trail
# 10479            Mount Falcon and Lair O' the Bear Loop
# 10482                             Meyer Ranch Full Loop
# 10497    Dakota Ridge / Red Rocks loop from Zorro trail
# 10500                                 Deer Creek Canyon
# 10502                        Green Mountain Novice Loop
# 10504                                  Hildebrand Ranch
# 10505                  Green Mountain Intermediate Loop
# 10507        Mount Falcon - The best of the singletrack
# 10511                    Bear Creek - Dakota Ridge Loop
# 10512                                    Front Range 30
# 10513                                     XC Loop Trail
# 10514                                    Mt Carbon Loop
# 10515                                Dakota Ridge Trail
# 10516                                   Red Rocks Trail
# 10517                                      Castle Trail
# 10518                                    Parmalee Trail
# 10519                              Box o' Rox Extension
# 10520                          South Dakota Ridge Trail
# 10522     CT - Segment 1: Chatfield to S. Platte Canyon
# 10533                               Rooney Valley Trail
# 10539                                     Devil's Elbow
# 10556                               Green Mountain Loop
# 10557                                      Prairie Loop
# 10561                                           Old Ute
# 10564                                         Hill Loop
# 10571                            Wildcat Mountain Trail
# 10584                              Morrison Slide Trail
# 10598                              Plymouth Creek Trail
# 10599                                  Cottonwood Creek
#                               ...
# 11390                                      Belcher Hill
# 11413                                   Shorthorn Trail
# 11421                                        Box o' Rox
# 11427                                         Sluicebox
# 11432                                          Rim Rock
# 11434                                    Pick N' Sledge
# 11440                                         Grubstake
# 11467                               Golden Summit Trail
# 11469                           Cottonwood Canyon Trail
# 11471                                       Whippletree
# 11480                                    Tertiary Trail
# 11483                            Lookout Mountain Trail
# 11484                           Westminster Hills Trail
# 11486                                     Round-Up Loop
# 11493                                North Access Trail
# 11495                         Neighborhood Access Trail
# 11499                                  Cretaceous Trail
# 11501                                       Argos Trail
# 11502                                   Basalt Cap Loop
# 11504                                          Mesa Top
# 11510                               Ancient Palms Trail
# 11511                               Big Dry Creek Trail
# 11513                           Grange Hall Creek Trail
# 11514                                   Perimeter Trail
# 15684                                  Old Quarry Trail
# 16547                                      Fossil Trail
# 16580                      Westminster Hills Loop Trail
# 16594                                Tilting Mesa Trail
# 16596                                      Lithic Trail
# 16610                                        Outer Loop
# Name: name, Length: 112, dtype: object

# %%
#dfd.loc[dfd.index[[0, 2]], 'A']
new_lat_lon = (df.loc[11427]['latitude'], df.loc[11427]['longitude'])
new_lat_lon
# Out:
# (39.717799999999997, -105.2302)

# %%
lat_lon
# Out:
# (39.6795193, -104.9969322)

# %%
new_lat_lon
# Out:
# (39.717799999999997, -105.2302)

# %%
vincenty(lat_lon, new_lat_lon).miles
# Out:
# 12.709150685596637

# %%
df.index
# Out:
# Int64Index([10472, 10479, 10482, 10497, 10500, 10502, 10504, 10505, 10507,
#             10511,
#             ...
#             11510, 11511, 11513, 11514, 15684, 16547, 16580, 16594, 16596,
#             16610],
#            dtype='int64', length=112)

# %%
df.loc[10472]
# Out:
# name                                Lair O' the Bear - Bear Creek Trail
# location                                              Genesee, Colorado
# difficulty                                                         Blue
# length                                                             12.2
# ascent                                                             1673
# descent                                                           -1673
# stars                                                                 4
# latitude                                                        39.6676
# longitude                                                      -105.257
# summary               Mostly flowy singletrack, with a few small cli...
# url                   https://www.mtbproject.com/trail/703097/lair-o...
# difficulty_encoded                                                    3
# category                                                  Featured Ride
# type_Featured Ride                                                    1
# type_Trail                                                            0
# city/town                                                       Genesee
# state                                                          Colorado
# length_range                                                      10-15
# Name: 10472, dtype: object

# %%
'''
def get_vincenty(num):
    new_lat_lon = (df.loc[num]['latitude'], df.loc[num]['longitude'])
    return round(vincenty(lat_lon, new_lat_lon).miles,1)

df['miles_away'] = df.index.map(get_vincenty)
#this was a good idea but I kept having errors with the index
'''
# Out:
# "\ndef get_vincenty(num):\n    new_lat_lon = (df.loc[num]['latitude'], df.loc[num]['longitude'])\n    return round(vincenty(lat_lon, new_lat_lon).miles,1)\n\ndf['miles_away'] = df.index.map(get_vincenty)\n#this was a good idea but I kept having errors with the index\n"

# %%
US_trails['difficulty'].value_counts()
# Out:
# Blue            6782
# Green/Blue      4560
# Blue/Black      3491
# Green           3100
# Black           2320
# Double Black     438
# Name: difficulty, dtype: int64

# %%
US_trails['length_range'].value_counts()
# Out:
# 0-5       16279
# 5-10       2381
# 10-15       995
# 15-20       452
# 20-25       251
# 30-50       149
# 25-30       112
# 50-100       49
# 100+         23
# Name: length_range, dtype: int64

# %%
US_trails.dtypes
# Out:
# name                   object
# location               object
# difficulty             object
# length                float64
# ascent                  int64
# descent                 int64
# stars                 float64
# latitude              float64
# longitude             float64
# summary                object
# url                    object
# difficulty_encoded      int64
# category               object
# type_Featured Ride      int64
# type_Trail              int64
# city/town              object
# state                  object
# length_range           object
# dtype: object

# %%
def get_vincenty(row, *args):
    new_lat_lon = (row['latitude'], row['longitude'])    
    #return round(vincenty(args[0], new_lat_lon).miles,1)
    return round(vincenty(args[0], new_lat_lon).miles,1)

#df['miles_away'] = df.apply(get_vincenty, axis = 1)

# %%
def cold_start(start, miles, length_range = None, difficulty = None):
    #these are units of measurement that we will need in determining our lat/lon change
    earth_radius = 3960.0
    degrees_to_radians = math.pi/180.0
    radians_to_degrees = 180.0/math.pi
    
    #the geolocator starts an instance of Google's API so we can get the lat/lon of the starting location
    geolocator = GoogleV3()
    location = geolocator.geocode(start)
    location_lat_lon = (location.latitude, location.longitude)
    print (location.address)
    
    '''
    Convert the miles into a latitude difference: since an arc length(in miles) is represented by miles = radius * angle(in radians),
    then the latitude angle can be solved by angle = miles/earth_radius and then converted into degrees with radians_to_degrees.
    Since the longitude conversion of miles into degrees depends on the latitude, for longitude miles = earth_radius * theta * cos(lat_degree)
    where cos(lat_degree) is the proportion of the circle of latitude to the circle around the equator with the earth's radius.
    This makes sense because if we are at the equator, the radius of the latitude circle is equal to the radius of the earth;
    therefore cos(latitude angle) = 1, making the longitude miles = earth_radius * longitude_angle.  To solve for the 
    longitude angle, we get longitude_angle = miles/(earth_radius*cos(longitude_angle)).
    '''
    lat_diff = (miles/earth_radius)*radians_to_degrees
    r = earth_radius*math.cos(location_lat_lon[0]*degrees_to_radians)
    lon_diff = (miles/r)*radians_to_degrees
    
    #we now add/subtract the lat_diff and lon_diff in degrees from the lat/lon of our current location 
    #to find the range of lat and lon degrees from which we'll take our trails
    lat_range = (location_lat_lon[0] - lat_diff, location_lat_lon[0] + lat_diff)
    lon_range = (location_lat_lon[1] - lon_diff, location_lat_lon[1] + lon_diff)
    
    #we know create a datraframe that only includes trails within our lat and lon ranges
    df = US_trails[(US_trails['latitude'] >= lat_range[0]) & (US_trails['latitude'] <= lat_range[1])]
    df = df[(df['longitude'] >= lon_range[0]) & (df['longitude'] <= lon_range[1])]
    #could possibly put this in one line but that would be long
  
    #if a length_range for desired trails is given, we limit our dataframe to only include trails within that range
    if length_range == '0-5':
        df = df[df['length_range'] == '0-5']
    if length_range == '5-10':
        df = df[df['length_range'] == '5-10']
    if length_range == '10-15':
        df = df[df['length_range'] == '10-15']
    if length_range == '15-20':
        df = df[df['length_range'] == '15-20']
    if length_range == '20-25':
        df = df[df['length_range'] == '20-25']
    if length_range == '25-30':
        df = df[df['length_range'] == '25-30']
    if length_range == '30-50':
        df = df[df['length_range'] == '30-50']
    if length_range == '50-100':
        df = df[df['length_range'] == '50-100']
    if length_range == '100+':
        df = df[df['length_range'] == '100+']
        
    #if a difficulty for desired trails is given, we limit our dataframe to only include trails that have that difficulty
    if difficulty == 'Green':
        difficulties = ['Green', 'Green/Blue']
        df = df[df['difficulty'].isin(difficulties)]
    if difficulty == 'Blue':
        difficulties = ['Green/Blue', 'Blue', 'Blue/Black']
        df = df[df['difficulty'].isin(difficulties)]
    if difficulty == 'Black':
        difficulties = ['Blue/Black', 'Black', 'Double Black']
        df = df[df['difficulty'].isin(difficulties)]
    
    #if there's no trails that fit all these requirements, we must give a warning so they don't wonder why there's an empty df
    if df.shape[0] == 0:
        return "There are no trails that meet your requirements. Try expanding your search."
    
    #add a column to our df that includes the miles away that each trail is from our location using the vincenty distance measurement
    else:
        #df['miles_away'] = df.index.map(get_vincenty)
        df['miles_away'] = df.apply(get_vincenty, axis = 1, args = (location_lat_lon,))
        columns_to_output = ['name', 'location', 'stars', 'difficulty', 'length', 'ascent', 'descent',
            'category', 'miles_away', 'summary', 'url']
        return df[columns_to_output].sort_values('miles_away')
    
'''
make it optional to put in a distance_length_range max(might need to encode these so I can return the trails that have 
less than that range, or more), and might need to make a column for location, state
also do this for difficulty
#if you want to ride 15 - 20, just give back 15 - 20
#if you want mostly green, do green and green/blue
#if you want mostly blue, do green/blue, blue, blue/black
#if you want mostly black, do blue/black, black, double black
'''
# Out:
# '\nmake it optional to put in a distance_length_range max(might need to encode these so I can return the trails that have \nless than that range, or more), and might need to make a column for location, state\nalso do this for difficulty\n#if you want to ride 15 - 20, just give back 15 - 20\n#if you want mostly green, do green and green/blue\n#if you want mostly blue, do green/blue, blue, blue/black\n#if you want mostly black, do blue/black, black, double black\n'

# %%
#cold_start('2044 South Huron Street Denver', 15, difficulty = 'Black')
cold_start('2044 South Huron Street Denver', 15, length_range = '0-5', difficulty = 'Black')
# Out:
# 2044 S Huron St, Denver, CO 80223, USA
#                            name                      location  stars  \
# 10519      Box o' Rox Extension  West Pleasant View, Colorado    4.2
# 10520  South Dakota Ridge Trail            Morrison, Colorado    4.8
# 10670                     Zorro            Morrison, Colorado    3.0
# 10517              Castle Trail            Morrison, Colorado    3.6
# 10515        Dakota Ridge Trail            Morrison, Colorado    4.3
# 10584      Morrison Slide Trail            Morrison, Colorado    3.3
# 11434            Pick N' Sledge              Golden, Colorado    3.6
# 10598      Plymouth Creek Trail           Ken Caryl, Colorado    3.5
# 10539             Devil's Elbow        Indian Hills, Colorado    4.1
# 10561                   Old Ute        Indian Hills, Colorado    4.0
# 11427                 Sluicebox              Golden, Colorado    3.8
# 11440                 Grubstake              Golden, Colorado    3.6
# 10518            Parmalee Trail        Indian Hills, Colorado    4.0
# 11384             Chimney Gulch              Golden, Colorado    3.6
# 11382          Enchanted Forest              Golden, Colorado    4.7
# 11383                Apex Trail             Genesee, Colorado    4.1
# 11390              Belcher Hill              Golden, Colorado    2.7
# 11413           Shorthorn Trail              Golden, Colorado    3.6
#
#        difficulty  length  ascent  descent category  miles_away  \
# 10519  Blue/Black     0.6       0     -150    Trail        10.4
# 10520       Black     0.6      46      -95    Trail        10.4
# 10670  Blue/Black     1.0       0     -383    Trail        10.8
# 10517  Blue/Black     3.9    1740        0    Trail        10.9
# 10515       Black     2.7     349     -706    Trail        11.1
# 10584       Black     1.4     285     -360    Trail        11.2
# 11434  Blue/Black     1.5     713      -18    Trail        12.1
# 10598       Black     2.3    1092      -56    Trail        12.5
# 10539  Blue/Black     0.9      91     -156    Trail        12.5
# 10561  Blue/Black     0.5      95      -80    Trail        12.6
# 11427       Black     0.7       0     -343    Trail        12.7
# 11440  Blue/Black     1.5     146     -352    Trail        12.7
# 10518  Blue/Black     2.3     366     -484    Trail        13.2
# 11384  Blue/Black     2.3    1126      -15    Trail        13.3
# 11382  Blue/Black     1.5      49     -495    Trail        13.6
# 11383       Black     2.8       0    -1280    Trail        13.8
# 11390  Blue/Black     4.5    1733     -437    Trail        15.7
# 11413       Black     1.1     176     -238    Trail        17.5
#
#                                                  summary  \
# 10519  A COMBA-built trail offering flow, berms, jump...
# 10520    A lollipop extension of the Dakota Ridge Trail.
# 10670  A singletrack connector between Dakota Ridge a...
# 10517  Not a super technical climb but nonetheless de...
# 10515                    A technical, rocky, fast trail.
# 10584     An alternate route off of the Red Rocks Trail.
# 11434                  An alternate climb up Apex trail.
# 10598  The main trail connecting you to the Red Mesa ...
# 10539  A nice little loop with some great views and i...
# 10561  A short loop with some interesting rock features.
# 11427  A technical, twisty trail connecting Hardscrab...
# 11440  A fun ride (when done clockwise) with few peop...
# 10518  A fun descent that punches back up to Meadow T...
# 11384  A steep but mostly smooth climb riding up Look...
# 11382  A super fun ride through the trees as an alter...
# 11383  A tough climb up a rocky technical valley, or ...
# 11390  A massive climb up the center of White Ranch O...
# 11413                An alternate route off of Longhorn.
#
#                                                      url
# 10519  https://www.mtbproject.com/trail/7027217/box-o...
# 10520  https://www.mtbproject.com/trail/7030099/south...
# 10670      https://www.mtbproject.com/trail/163982/zorro
# 10517  https://www.mtbproject.com/trail/702276/castle...
# 10515  https://www.mtbproject.com/trail/605246/dakota...
# 10584  https://www.mtbproject.com/trail/656058/morris...
# 11434  https://www.mtbproject.com/trail/603826/pick-n...
# 10598  https://www.mtbproject.com/trail/1366318/plymo...
# 10539  https://www.mtbproject.com/trail/4442994/devil...
# 10561   https://www.mtbproject.com/trail/4443458/old-ute
# 11427  https://www.mtbproject.com/trail/603872/sluicebox
# 11440  https://www.mtbproject.com/trail/3911886/grubs...
# 10518  https://www.mtbproject.com/trail/900167/parmal...
# 11384  https://www.mtbproject.com/trail/603155/chimne...
# 11382  https://www.mtbproject.com/trail/616137/enchan...
# 11383  https://www.mtbproject.com/trail/603762/apex-t...
# 11390  https://www.mtbproject.com/trail/631792/belche...
# 11413  https://www.mtbproject.com/trail/632607/shorth...

# %%
cold_start('1182 Shepherds Lane Atlanta', 10)
# Out:
# 1182 Shepherds Ln NE, Atlanta, GA 30324, USA
#                     name          location  stars  difficulty  length  ascent  \
# 3170          Sope Creek  Vinings, Georgia    4.1  Green/Blue     8.8     537
# 2473  Silver Comet Trail   Smyrna, Georgia    3.0       Green    63.5    1797
#
#       descent category  miles_away  \
# 3170     -525    Trail         8.7
# 2473    -1837    Trail         9.8
#
#                                                 summary  \
# 3170  Sope Creek has a few miles of gravel and some ...
# 2473                                    Needs Adoption!
#
#                                                     url
# 3170  https://www.mtbproject.com/trail/5545346/sope-...
# 2473  https://www.mtbproject.com/trail/7004601/silve...

# %%
cold_start('690 North Pearl Street Denver', 15)
# Out:
# 690 Pearl St, Denver, CO 80203, USA
#                                       name                        location  \
# 10513                        XC Loop Trail             Englewood, Colorado
# 16610                           Outer Loop           Wheat Ridge, Colorado
# 10701                   Blackmer Lake Loop  Cherry Hills Village, Colorado
# 11514                      Perimeter Trail         Commerce City, Colorado
# 10557                         Prairie Loop            Centennial, Colorado
# 10564                            Hill Loop            Centennial, Colorado
# 10639            Prairie Loop to Trailhead            Centennial, Colorado
# 10699           Beginner Loop to Hill Loop            Centennial, Colorado
# 10502           Green Mountain Novice Loop    West Pleasant View, Colorado
# 10652                         Hayden Trail              Morrison, Colorado
# 11480                       Tertiary Trail             Applewood, Colorado
# 11493                   North Access Trail    West Pleasant View, Colorado
# 10511       Bear Creek - Dakota Ridge Loop              Morrison, Colorado
# 10514                       Mt Carbon Loop              Morrison, Colorado
# 11502                      Basalt Cap Loop             Applewood, Colorado
# 10702                   Railroad Bed Trail           Dove Valley, Colorado
# 10635                    Summit Loop Trail    West Pleasant View, Colorado
# 10611                          Parker Road           Dove Valley, Colorado
# 11499                     Cretaceous Trail    West Pleasant View, Colorado
# 10675                          Cowen Trail              Morrison, Colorado
# 11510                  Ancient Palms Trail             Applewood, Colorado
# 15684                     Old Quarry Trail             Applewood, Colorado
# 11513              Grange Hall Creek Trail            Northglenn, Colorado
# 10695              Rooney Valley Connector    West Pleasant View, Colorado
# 10612                           Cottonwood              Morrison, Colorado
# 10533                  Rooney Valley Trail    West Pleasant View, Colorado
# 10680                     North Park Trail              Morrison, Colorado
# 10599                     Cottonwood Creek           Dove Valley, Colorado
# 16547                         Fossil Trail    West Pleasant View, Colorado
# 11421                           Box o' Rox    West Pleasant View, Colorado
# ...                                    ...                             ...
# 10705                  Cathy Johnson Trail             Ken Caryl, Colorado
# 10539                        Devil's Elbow          Indian Hills, Colorado
# 10673                    Grazing Elk Trail             Ken Caryl, Colorado
# 10698                         Meadow Trail          Indian Hills, Colorado
# 10561                              Old Ute          Indian Hills, Colorado
# 10694                          Tower Trail          Indian Hills, Colorado
# 10663                         Outlaw Trail       Highlands Ranch, Colorado
# 10607                             Giddy Up       Highlands Ranch, Colorado
# 10614                            Wild West       Highlands Ranch, Colorado
# 10667                       Longhorn Ledge       Highlands Ranch, Colorado
# 10518                       Parmalee Trail          Indian Hills, Colorado
# 11331  White Ranch: Technical Descent Tour                Golden, Colorado
# 11390                         Belcher Hill                Golden, Colorado
# 10678                    Bruin Bluff Trail               Genesee, Colorado
# 10472  Lair O' the Bear - Bear Creek Trail               Genesee, Colorado
# 11512                      Lake Link Trail            Broomfield, Colorado
# 10598                 Plymouth Creek Trail             Ken Caryl, Colorado
# 10500                    Deer Creek Canyon             Ken Caryl, Colorado
# 16586                     Rock Creek Trail            Broomfield, Colorado
# 10655              Plymouth Mountain Trail             Ken Caryl, Colorado
# 10609                        Red Mesa Loop             Ken Caryl, Colorado
# 16639                              Coalton              Superior, Colorado
# 16589                Flatirons Vista North              Superior, Colorado
# 11500                          High Plains              Superior, Colorado
# 16565                    Greenbelt Plateau              Superior, Colorado
# 11506                        Prairie Vista              Superior, Colorado
# 11482                Flatirons Vista South              Superior, Colorado
# 11468              Spring Brook Loop South              Superior, Colorado
# 11475                           Doudy Draw              Superior, Colorado
# 11334     Marshall Mesa - Doudy Draw Loops              Superior, Colorado
#
#        stars  difficulty  length  ascent  descent       category  miles_away  \
# 10513    3.0  Green/Blue     1.7     130     -130  Featured Ride         3.3
# 16610    2.0        Blue     2.6      53      -55          Trail         6.8
# 10701    2.5       Green     1.0      34      -41          Trail         6.9
# 11514    2.0       Green    22.2     333     -332          Trail         7.6
# 10557    3.7  Green/Blue     1.0      50      -52          Trail         8.0
# 10564    3.5  Green/Blue     0.5      50      -49          Trail         8.1
# 10639    3.7       Green     0.6      48       -2          Trail         8.1
# 10699    2.5       Green     0.2       0      -30          Trail         8.2
# 10502    3.1  Green/Blue     5.9     983     -995  Featured Ride         9.5
# 10652    3.3        Blue     1.7     629      -13          Trail         9.7
# 11480    3.5  Green/Blue     0.5       0     -199          Trail         9.9
# 11493    3.3  Green/Blue     2.0     621      -27          Trail         9.9
# 10511    3.0        Blue    19.8    1719    -1709  Featured Ride         9.9
# 10514    3.7  Green/Blue     7.3     556     -549          Trail         9.9
# 11502    3.0       Green     1.5      37      -41          Trail         9.9
# 10702    2.5  Green/Blue     2.0      70      -10          Trail        10.0
# 10635    3.2  Green/Blue     2.7     218      -78          Trail        10.0
# 10611    4.0       Green     2.4     121      -44          Trail        10.1
# 11499    3.3  Green/Blue     1.0     263       -6          Trail        10.2
# 10675    3.0  Green/Blue     1.4      56      -46          Trail        10.2
# 11510    3.0        Blue     1.0       0     -289          Trail        10.3
# 15684    3.0       Green     1.0      60      -30          Trail        10.3
# 11513    2.5       Green     4.7       7     -247          Trail        10.4
# 10695    2.8  Green/Blue     1.0      19     -239          Trail        10.6
# 10612    4.0       Green     0.4      28       -5          Trail        10.6
# 10533    3.4        Blue     2.5      97     -769          Trail        10.7
# 10680    2.7       Green     3.0     193     -157          Trail        10.7
# 10599    4.0       Green     1.9       1      -52          Trail        10.9
# 16547    3.0  Green/Blue     0.7     138        0          Trail        11.2
# 11421    3.3        Blue     1.5     484      -52          Trail        11.3
# ...      ...         ...     ...     ...      ...            ...         ...
# 10705    2.0       Green     2.1     364     -119          Trail        14.5
# 10539    4.1  Blue/Black     0.9      91     -156          Trail        14.5
# 10673    2.6       Green     3.1     267     -221          Trail        14.6
# 10698    2.5  Green/Blue     0.9     150      -59          Trail        14.6
# 10561    4.0  Blue/Black     0.5      95      -80          Trail        14.7
# 10694    2.7        Blue     0.6     217     -119          Trail        14.8
# 10663    3.3       Green     1.4      55     -142          Trail        14.9
# 10607    4.0       Green     0.6      76      -44          Trail        14.9
# 10614    4.0       Green     1.3     149      -66          Trail        14.9
# 10667    3.2  Green/Blue     1.4     241      -28          Trail        14.9
# 10518    4.0  Blue/Black     2.3     366     -484          Trail        15.1
# 11331    4.0       Black    13.6    2799    -2800  Featured Ride        15.1
# 11390    2.7  Blue/Black     4.5    1733     -437          Trail        15.1
# 10678    3.0  Green/Blue     1.1     168     -155          Trail        15.2
# 10472    4.0        Blue    12.2    1673    -1673  Featured Ride        15.3
# 11512    2.5  Green/Blue     8.8     346     -498          Trail        15.4
# 10598    3.5       Black     2.3    1092      -56          Trail        15.6
# 10500    3.9       Black    10.1    2171    -2170  Featured Ride        15.6
# 16586    2.3       Green     0.9       0     -127          Trail        15.9
# 10655    3.3        Blue     2.1     394     -340          Trail        16.6
# 10609    3.8        Blue     2.4     372     -349          Trail        16.6
# 16639    1.5       Green     2.8     398        0          Trail        17.1
# 16589    2.0       Green     1.2     190        0          Trail        19.2
# 11500    3.0  Green/Blue     2.7     167     -108          Trail        19.4
# 16565    2.3       Green     1.4       0     -174          Trail        19.4
# 11506    2.9       Green     1.1       0     -188          Trail        19.4
# 11482    2.8       Green     2.1      81     -223          Trail        19.9
# 11468    3.2        Blue     1.4     299       -5          Trail        20.1
# 11475    2.9  Green/Blue     2.2     449       -4          Trail        20.7
# 11334    3.6  Green/Blue    10.3     960     -961  Featured Ride        20.7
#
#                                                  summary  \
# 10513  A fast, flowy XC loop (clockwise) with a littl...
# 16610  An easy mix of paved path, singletrack, and do...
# 10701                 A short loop around Blackmer Lake.
# 11514     A flat, mostly-gravel loop with cool wildlife.
# 10557  The second loop of Village Greens North Mounta...
# 10564  A fun loop with easy and technical options thr...
# 10639     Get back to the car after lapping Prairie Loop
# 10699  A quick gravel trail with a few obstacles to g...
# 10502  A relatively quick loop of great singletrack w...
# 10652  A good connector from the Green Mountain Loop ...
# 11480               A short little singletrack downhill.
# 11493  A flowy access to the summit of Green Mountain...
# 10511  Suburban singletrack in the heart of Southwest...
# 10514  Singletrack that circumnavigates Bear Creek La...
# 11502  A flat doubletrack loop on top of South Table ...
# 10702          A trail that follows an old railroad bed.
# 10635  A fun chunky loop around the summit of Green M...
# 10611  A paved path along the northeast side of Cherr...
# 11499                      Singletrack with small rocks.
# 10675  This singletrack trail heads south off the Mt ...
# 11510                    Singletrack with smaller rocks.
# 15684  Dirt and gravel doubletrack trail on top of So...
# 11513  This section of the Grange Hall Creek Trail ru...
# 10695  Another section of the Rooney Valley trail con...
# 10612    Playful, swooping singletrack along Bear Creek.
# 10533  A slightly more difficult trail cutting throug...
# 10680  The North Park Trail connects to the Mt Carbon...
# 10599        A scenic trail through a riparian corridor.
# 16547                     Needs summary and description.
# 11421    Fun, steep, and loose with some rocks and sand.
# ...                                                  ...
# 10705  A pleasant ride between the Dakota and Lyons h...
# 10539  A nice little loop with some great views and i...
# 10673  Easy trail with scenic views of the Ken Caryl ...
# 10698  Nice trail that connects you to the more inter...
# 10561  A short loop with some interesting rock features.
# 10694  A nice view to take a breather and maybe eat l...
# 10663  A fairly heavily traveled trunk of the backcou...
# 10607  Flowy singletrack linking Tenderfoot Trail to ...
# 10614  A winding singletrack in the heart of Highland...
# 10667  A flowy gravel singletrack in the Highlands Ra...
# 10518  A fun descent that punches back up to Meadow T...
# 11331  A tour of the southern half of White Ranch's b...
# 11390  A massive climb up the center of White Ranch O...
# 10678  A fun and mellow follow up to the Lair o' the ...
# 10472  Mostly flowy singletrack, with a few small cli...
# 11512  A doubletrack, gravel/paved all-weather trail/...
# 10598  The main trail connecting you to the Red Mesa ...
# 10500      A technical downhill earned the Colorado way.
# 16586  New in 2014, this trail connects Broomfield to...
# 10655  A scenic loop encircling Plymouth Mountain, wi...
# 10609  Singletrack with great views of the south Denv...
# 16639  A mostly doubletrack/dirt road section connect...
# 16589  A short trail that connects the northern secti...
# 11500  All singletrack, and slightly more technical t...
# 16565  A simple mix of doubletrack and dirt road that...
# 11506  Another mellow trail option at the southern en...
# 11482  A mellow cruise through open forest at the sou...
# 11468  The first half of the Spring Brook Loop if rid...
# 11475  The main artery through the Marshall Mesa trai...
# 11334  A nice ride close to Boulder - great views and...
#
#                                                      url
# 10513  https://www.mtbproject.com/trail/7032397/xc-lo...
# 16610  https://www.mtbproject.com/trail/7030025/outer...
# 10701  https://www.mtbproject.com/trail/7002900/black...
# 11514  https://www.mtbproject.com/trail/7022012/perim...
# 10557  https://www.mtbproject.com/trail/7003521/prair...
# 10564  https://www.mtbproject.com/trail/7003520/hill-...
# 10639  https://www.mtbproject.com/trail/7003522/prair...
# 10699  https://www.mtbproject.com/trail/7003517/begin...
# 10502  https://www.mtbproject.com/trail/3638243/green...
# 10652  https://www.mtbproject.com/trail/7003415/hayde...
# 11480  https://www.mtbproject.com/trail/7007863/terti...
# 11493  https://www.mtbproject.com/trail/7003972/north...
# 10511  https://www.mtbproject.com/trail/48905/bear-cr...
# 10514  https://www.mtbproject.com/trail/167268/mt-car...
# 11502  https://www.mtbproject.com/trail/7007866/basal...
# 10702  https://www.mtbproject.com/trail/7025017/railr...
# 10635  https://www.mtbproject.com/trail/730763/summit...
# 10611  https://www.mtbproject.com/trail/7024875/parke...
# 11499  https://www.mtbproject.com/trail/7007868/creta...
# 10675  https://www.mtbproject.com/trail/7013512/cowen...
# 11510  https://www.mtbproject.com/trail/7007869/ancie...
# 15684  https://www.mtbproject.com/trail/7030907/old-q...
# 11513  https://www.mtbproject.com/trail/7012010/grang...
# 10695  https://www.mtbproject.com/trail/4495865/roone...
# 10612  https://www.mtbproject.com/trail/164855/cotton...
# 10533  https://www.mtbproject.com/trail/4495607/roone...
# 10680  https://www.mtbproject.com/trail/5284012/north...
# 10599  https://www.mtbproject.com/trail/7025027/cotto...
# 16547  https://www.mtbproject.com/trail/7033433/fossi...
# 11421  https://www.mtbproject.com/trail/731398/box-o-rox
# ...                                                  ...
# 10705  https://www.mtbproject.com/trail/6511243/cathy...
# 10539  https://www.mtbproject.com/trail/4442994/devil...
# 10673  https://www.mtbproject.com/trail/6507545/grazi...
# 10698  https://www.mtbproject.com/trail/4444407/meado...
# 10561   https://www.mtbproject.com/trail/4443458/old-ute
# 10694  https://www.mtbproject.com/trail/4443911/tower...
# 10663  https://www.mtbproject.com/trail/7007364/outla...
# 10607  https://www.mtbproject.com/trail/7019680/giddy-up
# 10614  https://www.mtbproject.com/trail/7019678/wild-...
# 10667  https://www.mtbproject.com/trail/7007361/longh...
# 10518  https://www.mtbproject.com/trail/900167/parmal...
# 11331  https://www.mtbproject.com/trail/632917/white-...
# 11390  https://www.mtbproject.com/trail/631792/belche...
# 10678  https://www.mtbproject.com/trail/7023017/bruin...
# 10472  https://www.mtbproject.com/trail/703097/lair-o...
# 11512  https://www.mtbproject.com/trail/7001527/lake-...
# 10598  https://www.mtbproject.com/trail/1366318/plymo...
# 10500  https://www.mtbproject.com/trail/965209/deer-c...
# 16586  https://www.mtbproject.com/trail/7001529/rock-...
# 10655  https://www.mtbproject.com/trail/1367080/plymo...
# 10609  https://www.mtbproject.com/trail/1366671/red-m...
# 16639    https://www.mtbproject.com/trail/265341/coalton
# 16589  https://www.mtbproject.com/trail/522182/flatir...
# 11500  https://www.mtbproject.com/trail/265834/high-p...
# 16565  https://www.mtbproject.com/trail/266412/greenb...
# 11506  https://www.mtbproject.com/trail/522764/prairi...
# 11482  https://www.mtbproject.com/trail/521849/flatir...
# 11468  https://www.mtbproject.com/trail/521309/spring...
# 11475  https://www.mtbproject.com/trail/520626/doudy-...
# 11334  https://www.mtbproject.com/trail/520343/marsha...
#
# [107 rows x 11 columns]

# %%
cold_start('Iowa City, Iowa', 150)
# Out:
# Iowa City, IA, USA
#                                                 name                location  \
# 13820                           Clear Creek Greenway        Coralville, Iowa
# 13815                                            205     North Liberty, Iowa
# 13814                                            301     North Liberty, Iowa
# 13817                                            203     North Liberty, Iowa
# 13818                                            302     North Liberty, Iowa
# 13802                               204 - Hell Trail     North Liberty, Iowa
# 13813                                            202     North Liberty, Iowa
# 13816                                            303     North Liberty, Iowa
# 13812                                            201     North Liberty, Iowa
# 13811                                            304     North Liberty, Iowa
# 13824                                            105     North Liberty, Iowa
# 13821                                305 Novice Loop     North Liberty, Iowa
# 13810                                            101     North Liberty, Iowa
# 13800                                   Sugar Bottom     North Liberty, Iowa
# 13809                           101x Cyclocross Hill     North Liberty, Iowa
# 13823                                            102     North Liberty, Iowa
# 13822                                            103     North Liberty, Iowa
# 13805                                       104/104x     North Liberty, Iowa
# 13807  Sac & Fox Singletrack - Cedar River Segment 1      Cedar Rapids, Iowa
# 13808  Sac & Fox Singletrack - Cedar River segment 2            Marion, Iowa
# 13806                                      Frontside           Fairfax, Iowa
# 13801                                   Beverly Park           Fairfax, Iowa
# 13825                     Squaw Creek Multiuse Trail            Marion, Iowa
# 13826                                             CG            Marion, Iowa
# 13803                                   Troll Holler            Marion, Iowa
# 13819                                          Irene            Marion, Iowa
# 13827                                    Mercy Flush            Marion, Iowa
# 13804                                      Red Cedar            Marion, Iowa
# 14354                                       The Bowl            Vinton, Iowa
# 14353                             Riverside Overlook            Vinton, Iowa
# ...                                              ...                     ...
# 11534              Thompson River Trail - South Loop       Trenton, Missouri
# 11535                      Northwest Connector (WC3)       Trenton, Missouri
# 11533                    Steep Creek Connector (WC2)       Trenton, Missouri
# 15089                                     Cannonball    Cambridge, Wisconsin
# 15073                                       Beer Run    Cambridge, Wisconsin
# 15075                                     Blue Dream    Cambridge, Wisconsin
# 15077                                Getting Started    Cambridge, Wisconsin
# 15078                                    Rattlesnake    Cambridge, Wisconsin
# 15081                                      Beer Cave    Cambridge, Wisconsin
# 15070                           Cam-Rock Park Area 3    Cambridge, Wisconsin
# 15088                                       Stonefly    Cambridge, Wisconsin
# 15080                                Mayor's Meander    Cambridge, Wisconsin
# 15083                                      Corkscrew    Cambridge, Wisconsin
# 15087                                      Woodchuck    Cambridge, Wisconsin
# 15076                            Corp Connector Loop    Cambridge, Wisconsin
# 15086                                     Turn It Up    Cambridge, Wisconsin
# 15079                                 Heather's Hill    Cambridge, Wisconsin
# 15082                                     Rip N Ride    Cambridge, Wisconsin
# 15085                               Raspberry Fields    Cambridge, Wisconsin
# 15072                                  Outback Trail    Cambridge, Wisconsin
# 15074                                        Veritas    Cambridge, Wisconsin
# 15084                                 IMBA Influence    Cambridge, Wisconsin
# 15071                   Corp Connector Two-Way Trail    Cambridge, Wisconsin
# 11553                       Gurgens Park Doubletrack       Sherman, Illinois
# 11552                     Carpenter Park Doubletrack       Sherman, Illinois
# 11550                Lewis Memorial Acres Outer Loop  Leland Grove, Illinois
# 11549                          West Lick Creek Trail       Chatham, Illinois
# 11548                          East Lick Creek Trail       Chatham, Illinois
# 11551                            Polecat Creek Trail       Chatham, Illinois
# 10737                                  Camp Camfield      Sullivan, Illinois
#
#        stars    difficulty  length  ascent  descent       category  \
# 13820    3.0    Green/Blue     2.4     223     -226          Trail
# 13815    4.0          Blue     0.4      69      -78          Trail
# 13814    4.0         Green     1.1     167     -207          Trail
# 13817    4.0          Blue     0.5      54      -54          Trail
# 13818    4.0          Blue     0.3      35      -33          Trail
# 13802    5.0         Black     0.8     129      -99          Trail
# 13813    4.0          Blue     0.2      41      -13          Trail
# 13816    4.0          Blue     0.5     109      -66          Trail
# 13812    4.0         Green     1.3     189     -187          Trail
# 13811    4.0         Black     0.8      56      -82          Trail
# 13824    3.0         Green     0.7      34      -75          Trail
# 13821    3.0         Green     0.6      31      -36          Trail
# 13810    4.0         Green     2.3     294     -233          Trail
# 13800    4.5          Blue    11.3    1560    -1558  Featured Ride
# 13809    4.0  Double Black     0.1       0       -4          Trail
# 13823    3.0         Black     0.3      21      -24          Trail
# 13822    3.0         Black     0.4      23      -19          Trail
# 13805    4.5         Black     1.1      83      -84          Trail
# 13807    4.0         Green     1.5      52      -55          Trail
# 13808    4.0         Green     1.2      52      -51          Trail
# 13806    4.0    Green/Blue     0.9     118     -110          Trail
# 13801    4.4          Blue     4.4     642     -641  Featured Ride
# 13825    2.0    Green/Blue     4.7     446     -441          Trail
# 13826    2.0    Blue/Black     0.3      70      -22          Trail
# 13803    5.0          Blue     0.3      37      -38          Trail
# 13819    3.7          Blue     2.1     311     -289          Trail
# 13827    0.0          Blue     0.1       0      -35          Trail
# 13804    4.7    Green/Blue     1.9     244     -249          Trail
# 14354    5.0    Blue/Black     0.1       4       -2          Trail
# 14353    5.0          Blue     0.4      18      -18  Featured Ride
# ...      ...           ...     ...     ...      ...            ...
# 11534    3.0          Blue     3.5     161     -159          Trail
# 11535    3.0          Blue     0.8      72      -91          Trail
# 11533    4.0          Blue     0.9      49      -63          Trail
# 15089    2.5         Green     2.5      55      -51          Trail
# 15073    4.0         Black     0.1      18      -22          Trail
# 15075    3.0          Blue     0.1       0      -16          Trail
# 15077    3.0         Green     0.2       3      -40          Trail
# 15078    3.0          Blue     0.4      17      -72          Trail
# 15081    3.0         Green     0.2      25      -24          Trail
# 15070    4.3          Blue     6.2     521     -521  Featured Ride
# 15088    3.0          Blue     0.2      30      -15          Trail
# 15080    3.0    Green/Blue     0.4      32      -41          Trail
# 15083    3.0          Blue     0.4      59      -34          Trail
# 15087    3.0         Green     0.7      35      -40          Trail
# 15076    3.0         Green     1.7      89      -98          Trail
# 15086    3.0          Blue     0.5     101      -53          Trail
# 15079    3.0          Blue     0.1      11       -6          Trail
# 15082    3.0          Blue     0.4      23      -45          Trail
# 15085    3.0          Blue     0.3      32       -9          Trail
# 15072    4.7         Black     0.6      14      -65          Trail
# 15074    3.5          Blue     0.3       7      -49          Trail
# 15084    3.0          Blue     0.3      21       -4          Trail
# 15071    5.0         Green     1.7      50      -28          Trail
# 11553    3.0         Green     3.7      27      -27          Trail
# 11552    3.0    Green/Blue     4.0      88      -95          Trail
# 11550    3.5    Green/Blue     1.3      60      -81          Trail
# 11549    3.6          Blue     1.2      35      -24          Trail
# 11548    3.7          Blue     1.1      43      -59          Trail
# 11551    3.5    Blue/Black     1.4      38      -41          Trail
# 10737    4.2    Green/Blue     6.6     149     -146  Featured Ride
#
#        miles_away                                            summary  \
# 13820         3.6  Winding singletrack between the Clear Creek pa...
# 13815         6.4  Fully in the pines with plenty of exposed root...
# 13814         6.4                            Great view of the lake!
# 13817         6.5  Amp up the roots and amp up the cardio with 20...
# 13818         6.5                                   Winding climbing
# 13802         6.5                         Makes you say, "Aw, hell!"
# 13813         6.6  Amp up the roots and amp up the cardio with 20...
# 13816         6.6        A technical section sneaks up near the end.
# 13812         6.7  An entertaining mix of twists and turns, ups a...
# 13811         6.8  Gets its black rating for some steep and rooty...
# 13824         6.8  Includes a few steeper, but not technical, des...
# 13821         6.8             Friendly to the beginner of beginners!
# 13810         6.9                                   It's a nice mix.
# 13800         6.9  Plenty of trail to please beginner through adv...
# 13809         7.1                          Calling all speed demons!
# 13823         7.3         Similar feel to 101, but more challenging.
# 13822         7.3  Short, steep root infested descents are a sign...
# 13805         7.3  Dominate the final ascending switchback and ca...
# 13807        20.2  Linear singletrack flowing through the woods &...
# 13808        20.7  A linear singletrack flowing through the woods...
# 13806        21.3  Gradual ascents and descents, wide turns and a...
# 13801        21.3  Fast - Flowing - Fun berms - Good mix of trail...
# 13825        23.6  Classic Midwestern off road multi-use doubletr...
# 13826        23.7              Tight and twisty Midwest singletrack!
# 13803        23.9  A long flowing boardwalk and rollercoaster tra...
# 13819        23.9  Blue (more difficult) Midwest singletrack pack...
# 13827        24.1  Steep, fast, and fun singletrack connecting th...
# 13804        24.2  Professionally built flowy singletrack that fe...
# 14354        43.4  A short trail portion including a nice skinny ...
# 14353        43.4  A short, fun singletrack with lots of options;...
# ...           ...                                                ...
# 11534       155.7          A great loop for those who like it rough.
# 11535       155.9  An alternate connecter between Tall Oaks Trail...
# 11533       155.9  A switchback connector between the Tall Oaks T...
# 15089       156.7  A multi-use gravel trail that runs the length ...
# 15073       156.8         A tight and twisty trail with steep berms.
# 15075       156.8                                      Needs Summary
# 15077       156.8                     Needs summary and description.
# 15078       156.8                     Needs summary and description.
# 15081       156.8                     Needs summary and description.
# 15070       156.8  Fairly short but fun singletrack. Some areas o...
# 15088       156.9                     Needs summary and description.
# 15080       156.9                                  Adopt this trail!
# 15083       156.9                     Needs summary and description.
# 15087       156.9                     Needs summary and description.
# 15076       157.1                                      Needs Summary
# 15086       157.1                     Needs summary and description.
# 15079       157.2                     Needs summary and description.
# 15082       157.4                     Needs summary and description.
# 15085       157.4                     Needs summary and description.
# 15072       157.5  Full of fun obstacles to challenge your skills...
# 15074       157.5                     Needs summary and description.
# 15084       157.6                     Needs summary and description.
# 15071       158.4  A quick fun ride along the creek. Suitable for...
# 11553       158.5  Beginner area or Sunday doubletrack stroll aro...
# 11552       159.1  Beginner area or Sunday doubletrack stroll aro...
# 11550       160.1  A beautiful singletrack loop around a small wa...
# 11549       165.0  Lollipop with inner loop.  Part of Lick Creek ...
# 11548       165.9  Point to point singletrack along Lake Springfi...
# 11551       166.2  Tight singletrack tucked into a small woodlot ...
# 10737       210.0  The best flowing and fun trail in this part of...
#
#                                                      url
# 13820  https://www.mtbproject.com/trail/7015001/clear...
# 13815       https://www.mtbproject.com/trail/4606280/205
# 13814       https://www.mtbproject.com/trail/4612447/301
# 13817       https://www.mtbproject.com/trail/4607377/203
# 13818       https://www.mtbproject.com/trail/4610767/302
# 13802  https://www.mtbproject.com/trail/4792388/204-h...
# 13813       https://www.mtbproject.com/trail/4606834/202
# 13816       https://www.mtbproject.com/trail/4611318/303
# 13812       https://www.mtbproject.com/trail/4605688/201
# 13811       https://www.mtbproject.com/trail/4611876/304
# 13824       https://www.mtbproject.com/trail/4605119/105
# 13821  https://www.mtbproject.com/trail/4604555/305-n...
# 13810       https://www.mtbproject.com/trail/4613602/101
# 13800  https://www.mtbproject.com/trail/4466318/sugar...
# 13809  https://www.mtbproject.com/trail/4607932/101x-...
# 13823       https://www.mtbproject.com/trail/4602329/102
# 13822       https://www.mtbproject.com/trail/4602880/103
# 13805   https://www.mtbproject.com/trail/4603970/104104x
# 13807  https://www.mtbproject.com/trail/7013435/sac-f...
# 13808  https://www.mtbproject.com/trail/7013438/sac-f...
# 13806  https://www.mtbproject.com/trail/4472744/front...
# 13801  https://www.mtbproject.com/trail/4465424/bever...
# 13825  https://www.mtbproject.com/trail/7002160/squaw...
# 13826        https://www.mtbproject.com/trail/7030952/cg
# 13803  https://www.mtbproject.com/trail/7030951/troll...
# 13819     https://www.mtbproject.com/trail/7002144/irene
# 13827  https://www.mtbproject.com/trail/7028557/mercy...
# 13804  https://www.mtbproject.com/trail/7028556/red-c...
# 14354  https://www.mtbproject.com/trail/7020292/the-bowl
# 14353  https://www.mtbproject.com/trail/7020268/river...
# ...                                                  ...
# 11534  https://www.mtbproject.com/trail/7028804/thomp...
# 11535  https://www.mtbproject.com/trail/7028808/north...
# 11533  https://www.mtbproject.com/trail/7028806/steep...
# 15089  https://www.mtbproject.com/trail/7026316/canno...
# 15073  https://www.mtbproject.com/trail/7026321/beer-run
# 15075  https://www.mtbproject.com/trail/7024941/blue-...
# 15077  https://www.mtbproject.com/trail/7026318/getti...
# 15078  https://www.mtbproject.com/trail/7023674/rattl...
# 15081  https://www.mtbproject.com/trail/7026317/beer-...
# 15070  https://www.mtbproject.com/trail/577682/cam-ro...
# 15088  https://www.mtbproject.com/trail/7023677/stonefly
# 15080  https://www.mtbproject.com/trail/7024940/mayor...
# 15083  https://www.mtbproject.com/trail/7023675/corks...
# 15087  https://www.mtbproject.com/trail/7023676/woodc...
# 15076  https://www.mtbproject.com/trail/7026308/corp-...
# 15086  https://www.mtbproject.com/trail/7026306/turn-...
# 15079  https://www.mtbproject.com/trail/7023698/heath...
# 15082  https://www.mtbproject.com/trail/7026314/rip-n...
# 15085  https://www.mtbproject.com/trail/7023691/raspb...
# 15072  https://www.mtbproject.com/trail/6504718/outba...
# 15074   https://www.mtbproject.com/trail/7023688/veritas
# 15084  https://www.mtbproject.com/trail/7023695/imba-...
# 15071  https://www.mtbproject.com/trail/6503923/corp-...
# 11553  https://www.mtbproject.com/trail/4489248/gurge...
# 11552  https://www.mtbproject.com/trail/4489324/carpe...
# 11550  https://www.mtbproject.com/trail/4489123/lewis...
# 11549  https://www.mtbproject.com/trail/4311045/west-...
# 11548  https://www.mtbproject.com/trail/4311189/east-...
# 11551  https://www.mtbproject.com/trail/4311229/polec...
# 10737  https://www.mtbproject.com/trail/4416102/camp-...
#
# [346 rows x 11 columns]

# %%
US_trails.loc[10737]
(39.49083302147416, 43.83142237852584)
(-94.43516851192199, -88.62516808807801)
# Out:
# (-94.43516851192199, -88.62516808807801)
