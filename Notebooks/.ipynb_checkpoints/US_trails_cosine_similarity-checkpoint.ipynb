# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
import warnings
warnings.filterwarnings('ignore')
#MIGHT HAVE TO ENCODE THE BINNING OF THE LENGTHS SO THIS CAN BE A 
#PARAMETER FOR A COLD START

# %%
US_trails = pd.read_csv('../US_trails_engineered.csv')

# %%
US_trails.columns
# Out:
# Index(['name', 'location', 'difficulty', 'length', 'ascent', 'descent',
#        'stars', 'latitude', 'longitude', 'summary', 'url',
#        'difficulty_encoded', 'category', 'type_Featured Ride', 'type_Trail',
#        'state', 'length_range'],
#       dtype='object')

# %%
quantitative_columns = list(US_trails.select_dtypes(exclude=['object']).columns)
quantitative_columns
# Out:
# ['length',
#  'ascent',
#  'descent',
#  'stars',
#  'latitude',
#  'longitude',
#  'difficulty_encoded',
#  'type_Featured Ride',
#  'type_Trail']

# %%
#this scales each column individually, BUT REALLY WHAT IS IT DOING?
for col in quantitative_columns:
    US_trails[col + "_scaled"] = preprocessing.scale(US_trails[col])

# %%
'''
#THIS DOES THE SAME AS ABOVE, EXCEPT THAT IT REWRITES ALL THE QUANTITATIVE COLUMNS WITH THEIR SCALED VALUES
scaler = preprocessing.StandardScaler()
scaler.fit(US_trails[quantitative_columns])
US_trails[quantitative_columns] = scaler.transform(US_trails[quantitative_columns])
US_trails.head()
'''
# Out:
# '\n#THIS DOES THE SAME AS ABOVE, EXCEPT THAT IT REWRITES ALL THE QUANTITATIVE COLUMNS WITH THEIR SCALED VALUES\nscaler = preprocessing.StandardScaler()\nscaler.fit(US_trails[quantitative_columns])\nUS_trails[quantitative_columns] = scaler.transform(US_trails[quantitative_columns])\nUS_trails.head()\n'

# %%
US_trails.columns
# Out:
# Index(['name', 'location', 'difficulty', 'length', 'ascent', 'descent',
#        'stars', 'latitude', 'longitude', 'summary', 'url',
#        'difficulty_encoded', 'category', 'type_Featured Ride', 'type_Trail',
#        'state', 'length_range', 'length_scaled', 'ascent_scaled',
#        'descent_scaled', 'stars_scaled', 'latitude_scaled', 'longitude_scaled',
#        'difficulty_encoded_scaled', 'type_Featured Ride_scaled',
#        'type_Trail_scaled'],
#       dtype='object')

# %%
scaled_cols = [col for col in US_trails.columns if 'scaled' in col]
scaled_cols
#US_trails_scaled = US_trails.filter(regex='scaled')
#US_trails_scaled.head()
# Out:
# ['length_scaled',
#  'ascent_scaled',
#  'descent_scaled',
#  'stars_scaled',
#  'latitude_scaled',
#  'longitude_scaled',
#  'difficulty_encoded_scaled',
#  'type_Connector_scaled',
#  'type_Featured Ride_scaled',
#  'type_Trail_scaled']

# %%
Big_X = US_trails[scaled_cols].values
Big_X
# Out:
# array([[ 2.34968482,  3.26943804, -3.10603287, ..., -0.48518339,
#          2.89092379, -1.53698176],
#        [ 0.0097693 , -0.01173064,  0.04261027, ..., -0.48518339,
#          2.89092379, -1.53698176],
#        [ 0.0097693 , -0.10878588,  0.12786032, ..., -0.48518339,
#          2.89092379, -1.53698176],
#        ...,
#        [-0.3064355 , -0.18245431,  0.44754799, ...,  2.06107634,
#         -0.34591019, -1.53698176],
#        [-0.43291742, -0.4291851 ,  0.44530457, ...,  2.06107634,
#         -0.34591019, -1.53698176],
#        [-0.43291742, -0.4350318 ,  0.44530457, ...,  2.06107634,
#         -0.34591019, -1.53698176]])

# %%
#this function will take in a state you ridden in, a trail you rode on, and the state you want to ride in and recommend
def cos_sim_recommendations(trail_name, state_name, scaled_features, n = 5, desired_state = None, desired_location= None):
    index = US_trails.index[(US_trails['name'] == trail_name) & (US_trails['State']==state_name)][0]
    #index is the index of the given trail in the main df based on it's name and state
    trail = scaled_features[index].reshape(1,-1)
    #trail is the scaled features of the given trail reshaped into a 1 row array
    cs = cosine_similarity(trail, scaled_features)
    #cs is the array of cosine similarity measurements of the trail compared to the scaled_features of the other trails
    rec_index = np.argsort(cs)[0][::-1][1:]
    #rec_index is an array of the indices of the cosine similarity measurements ordered by greatest to least, leaving out the given trail
    ordered_df = US_trails.loc[rec_index]
    #ordered_df gives the trails of US_trails ordered by the trails most similar to least similar
    if desired_state:
        ordered_df = ordered_df[ordered_df['State']== desired_state]
        #if a desired state to ride in is given, the dataframe is returned with trails only in that state
    if desired_location:
        ordered_df = ordered_df[ordered_df['location']== desired_location]
        #if a desired location to ride in is given, the dataframe is returned with trails only in that location
    rec_df = ordered_df.head(n)
    #rec_df is a dataframe with the number of desired trails to be recommended
    orig_row = US_trails.loc[[index]].rename(lambda x: 'original')
    #orig_row renames the index of the original trail given as 'original'
    total = pd.concat([orig_row, rec_df])
    #this combines the original row labeled as original row and the n recommended trails that are most similar to the original
    return total

# %%
cos_sim_recommendations("Mount Falcon and Lair O' the Bear Loop", 'Colorado', Big_X, n = 5, desired_state = 'Colorado', desired_location = 'Durango')
# Out:
#                                              name  location     State  \
# original   Mount Falcon and Lair O' the Bear Loop  Morrison  Colorado
# 7145           Grandview Ridge & Horse Gulch Loop   Durango  Colorado
# 8472                      Raiders Ridge Tech Loop   Durango  Colorado
# 8476                         Animas Mountain Loop   Durango  Colorado
# 7146      Sale Barn - South Rim - Carbon Junction   Durango  Colorado
# 8562                             Missionary Ridge   Durango  Colorado
#
#           difficulty  length  ascent  descent  stars  latitude  longitude  \
# original  Blue/Black    19.3    2655    -2660    3.6   39.6468  -105.1968
# 7145      Blue/Black    16.1    1822    -1830    4.0   37.2240  -107.8564
# 8472           Black     8.9    1376    -1360    3.7   37.2731  -107.8738
# 8476           Black     5.7    1492    -1494    3.3   37.3030  -107.8728
# 7146            Blue     7.2     752     -766    3.5   37.2238  -107.8563
# 8562      Blue/Black     7.0    1452     -699    3.5   37.3525  -107.8027
#
#                 ...          length_scaled ascent_scaled  descent_scaled  \
# original        ...               2.008184      2.669567       -2.536204
# 7145            ...               1.603441      1.695506       -1.605183
# 8472            ...               0.692772      1.173980       -1.077979
# 8476            ...               0.288030      1.309624       -1.228288
# 7146            ...               0.477752      0.444312       -0.411683
# 8562            ...               0.452456      1.262850       -0.336528
#
#           stars_scaled  latitude_scaled longitude_scaled  \
# original      0.383942         0.051045        -0.345581
# 7145          0.634053        -0.411321        -0.495728
# 8472          0.446470        -0.401950        -0.496710
# 8476          0.196358        -0.396244        -0.496654
# 7146          0.321414        -0.411359        -0.495722
# 8562          0.321414        -0.386798        -0.492696
#
#           difficulty_encoded_scaled  type_Connector_scaled  \
# original                   0.909315              -0.485183
# 7145                       0.909315              -0.485183
# 8472                       1.670197              -0.485183
# 8476                       1.670197              -0.485183
# 7146                       0.148433              -0.485183
# 8562                       0.909315              -0.485183
#
#           type_Featured Ride_scaled  type_Trail_scaled
# original                   2.890924          -1.536982
# 7145                       2.890924          -1.536982
# 8472                       2.890924          -1.536982
# 8476                       2.890924          -1.536982
# 7146                       2.890924          -1.536982
# 8562                      -0.345910           0.650626
#
# [6 rows x 26 columns]

# %%
cos_sim_recommendations("Mount Falcon and Lair O' the Bear Loop", 'Colorado', Big_X, n = 5, desired_state = 'Colorado', desired_location = 'Salida')
# Out:
#                                                        name  location  \
# original             Mount Falcon and Lair O' the Bear Loop  Morrison
# 10374                                       Cottonwood Tour    Salida
# 10387                     Monarch Crest to Agate Creek Loop    Salida
# 10390     Hwy 285/Mears Junction - CR 47YY/Silver Creek ...    Salida
# 10383     Rainbow Trail #1336: Hayden Creek to Methodist...    Salida
# 10377                               Monarch to Fooses Creek    Salida
#
#              State  difficulty  length  ascent  descent  stars  latitude  \
# original  Colorado  Blue/Black    19.3    2655    -2660    3.6   39.6468
# 10374     Colorado  Blue/Black    23.1    2540    -2539    4.2   38.5381
# 10387     Colorado       Black    36.6    4432    -4417    4.0   38.4383
# 10390     Colorado  Blue/Black    19.6    1437    -1396    4.0   38.4449
# 10383     Colorado       Black    31.8    6636    -5729    4.5   38.3300
# 10377     Colorado       Black    13.7     786    -3280    4.4   38.4960
#
#           longitude        ...          length_scaled ascent_scaled  \
# original  -105.1968        ...               2.008184      2.669567
# 10374     -105.9901        ...               2.488815      2.535092
# 10387     -106.3838        ...               4.196321      4.747484
# 10390     -106.1052        ...               2.046128      1.245310
# 10383     -105.8171        ...               3.589208      7.324710
# 10377     -106.3247        ...               1.299885      0.484070
#
#           descent_scaled  stars_scaled  latitude_scaled longitude_scaled  \
# original       -2.536204      0.383942         0.051045        -0.345581
# 10374          -2.400477      0.759109        -0.160539        -0.390366
# 10387          -4.507050      0.634053        -0.179585        -0.412593
# 10390          -1.118361      0.634053        -0.178325        -0.396864
# 10383          -5.978735      0.946693        -0.200252        -0.380600
# 10377          -3.231665      0.884165        -0.168573        -0.409256
#
#           difficulty_encoded_scaled  type_Connector_scaled  \
# original                   0.909315              -0.485183
# 10374                      0.909315              -0.485183
# 10387                      1.670197              -0.485183
# 10390                      0.909315              -0.485183
# 10383                      1.670197              -0.485183
# 10377                      1.670197              -0.485183
#
#           type_Featured Ride_scaled  type_Trail_scaled
# original                   2.890924          -1.536982
# 10374                      2.890924          -1.536982
# 10387                      2.890924          -1.536982
# 10390                      2.890924          -1.536982
# 10383                      2.890924          -1.536982
# 10377                      2.890924          -1.536982
#
# [6 rows x 26 columns]

# %%
#this function will take in a state you ridden in, a trail you rode on, and the state you want to ride in and recommend
def euclidean_dist_recommendations(trail_name, state_name, scaled_features, n = 5, desired_state = None, desired_location= None):
    index = US_trails.index[(US_trails['name'] == trail_name) & (US_trails['State']==state_name)][0]
    #index is the index of the given trail in the main df based on it's name and state
    trail = scaled_features[index].reshape(1,-1)
    #trail is the scaled features of the given trail reshaped into a 1 row array
    cs = euclidean_distances(trail, scaled_features)
    #cs is the array of euclidean distance measurements of the trail compared to the scaled_features of the other trails
    rec_index = np.argsort(cs)[0][::-1][1:]
    #rec_index is an array of the indices of the euclidean distance measurements ordered by greatest to least, leaving out the given trail
    ordered_df = US_trails.loc[rec_index]
    #ordered_df gives the trails of US_trails ordered by the trails most similar to least similar
    if desired_state:
        ordered_df = ordered_df[ordered_df['State']== desired_state]
        #if a desired state to ride in is given, the dataframe is returned with trails only in that state
    if desired_location:
        ordered_df = ordered_df[ordered_df['location']== desired_location]
        #if a desired location to ride in is given, the dataframe is returned with trails only in that location
    rec_df = ordered_df.head(n)
    #rec_df is a dataframe with the number of desired trails to be recommended
    orig_row = US_trails.loc[[index]].rename(lambda x: 'original')
    #orig_row renames the index of the original trail given as 'original'
    total = pd.concat([orig_row, rec_df])
    #this combines the original row labeled as original row and the n recommended trails that are most similar to the original
    return total

# %%
#THIS IS SOOOO MUCH WORSE!!!!! WHY????
euclidean_dist_recommendations("Mount Falcon and Lair O' the Bear Loop", 'Colorado', Big_X, n = 5, desired_state = 'Colorado', desired_location = 'Salida')
# Out:
#                                                        name  location  \
# original             Mount Falcon and Lair O' the Bear Loop  Morrison
# 10407     Colorado 14ers Loop: Segment 1 - Salida to Lea...    Salida
# 10610                                              Jalapeno    Salida
# 10580                                           Lil Rattler    Salida
# 10408                                           Uncle Nazty    Salida
# 10506                                             Burn Pile    Salida
#
#              State    difficulty  length  ascent  descent  stars  latitude  \
# original  Colorado    Blue/Black    19.3    2655    -2660    3.6   39.6468
# 10407     Colorado          Blue   139.1   17227   -14120    5.0   38.5357
# 10610     Colorado    Green/Blue     0.4      38      -15    3.5   38.5449
# 10580     Colorado    Green/Blue     0.9     198      -12    3.4   38.5444
# 10408     Colorado  Double Black     0.8       0     -439    4.6   38.5513
# 10506     Colorado          Blue     0.7       0     -243    3.7   38.5429
#
#           longitude        ...          length_scaled ascent_scaled  \
# original  -105.1968        ...               2.008184      2.669567
# 10407     -105.9952        ...              17.160718     19.709192
# 10610     -105.9930        ...              -0.382325     -0.390597
# 10580     -105.9885        ...              -0.319084     -0.203502
# 10408     -105.9726        ...              -0.331732     -0.435032
# 10506     -105.9876        ...              -0.344380     -0.435032
#
#           descent_scaled  stars_scaled  latitude_scaled longitude_scaled  \
# original       -2.536204      0.383942         0.051045        -0.345581
# 10407         -15.391013      1.259332        -0.160997        -0.390654
# 10610           0.430722      0.321414        -0.159241        -0.390530
# 10580           0.434087      0.258886        -0.159336        -0.390276
# 10408          -0.044883      1.009221        -0.158020        -0.389378
# 10506           0.174972      0.446470        -0.159623        -0.390225
#
#           difficulty_encoded_scaled  type_Connector_scaled  \
# original                   0.909315              -0.485183
# 10407                      0.148433              -0.485183
# 10610                     -0.612450              -0.485183
# 10580                     -0.612450              -0.485183
# 10408                      2.431079              -0.485183
# 10506                      0.148433              -0.485183
#
#           type_Featured Ride_scaled  type_Trail_scaled
# original                   2.890924          -1.536982
# 10407                     -0.345910           0.650626
# 10610                     -0.345910           0.650626
# 10580                     -0.345910           0.650626
# 10408                     -0.345910           0.650626
# 10506                     -0.345910           0.650626
#
# [6 rows x 26 columns]

# %%
cos_sim_recommendations("Mount Falcon and Lair O' the Bear Loop", 'Colorado', Big_X, n = 5, desired_state = 'Utah', desired_location = 'Moab')
# Out:
#                                             name  location     State  \
# original  Mount Falcon and Lair O' the Bear Loop  Morrison  Colorado
# 10098                                  Flat Pass      Moab      Utah
# 10096                               Zion Curtain      Moab      Utah
# 10041                            Jug Handle Loop      Moab      Utah
# 10035                                      Mag 7      Moab      Utah
# 10097                              Poison Spider      Moab      Utah
#
#           difficulty  length  ascent  descent  stars  latitude  longitude  \
# original  Blue/Black    19.3    2655    -2660    3.6   39.6468  -105.1968
# 10098     Blue/Black    18.2    2006    -2005    3.4   38.4763  -109.4220
# 10096     Blue/Black    17.9    1676    -1677    3.5   39.1956  -109.0513
# 10041           Blue    37.5    3247    -3249    3.8   38.5465  -109.6480
# 10035          Black    21.9    1815    -3849    4.6   38.5733  -109.7924
# 10097     Blue/Black    15.8    1580    -1580    2.6   38.5323  -109.6093
#
#                 ...          length_scaled ascent_scaled  descent_scaled  \
# original        ...               2.008184      2.669567       -2.536204
# 10098           ...               1.869054      1.910665       -1.801483
# 10096           ...               1.831109      1.524782       -1.433562
# 10041           ...               4.310155      3.361816       -3.196891
# 10035           ...               2.337037      1.687321       -3.869918
# 10097           ...               1.565497      1.412526       -1.324756
#
#           stars_scaled  latitude_scaled longitude_scaled  \
# original      0.383942         0.051045        -0.345581
# 10098         0.258886        -0.172333        -0.584114
# 10096         0.321414        -0.035062        -0.563186
# 10041         0.508998        -0.158936        -0.596873
# 10035         1.009221        -0.153821        -0.605025
# 10097        -0.241337        -0.161646        -0.594688
#
#           difficulty_encoded_scaled  type_Connector_scaled  \
# original                   0.909315              -0.485183
# 10098                      0.909315              -0.485183
# 10096                      0.909315              -0.485183
# 10041                      0.148433              -0.485183
# 10035                      1.670197              -0.485183
# 10097                      0.909315              -0.485183
#
#           type_Featured Ride_scaled  type_Trail_scaled
# original                   2.890924          -1.536982
# 10098                      2.890924          -1.536982
# 10096                      2.890924          -1.536982
# 10041                      2.890924          -1.536982
# 10035                      2.890924          -1.536982
# 10097                      2.890924          -1.536982
#
# [6 rows x 26 columns]

# %%
cos_sim_recommendations("Mount Falcon and Lair O' the Bear Loop", 'Colorado', Big_X, n = 5, desired_state = 'Virginia')
# Out:
#                                                   name        location  \
# original        Mount Falcon and Lair O' the Bear Loop        Morrison
# 11319     Braley's Pond & Confederate Breastworks Loop     Weyers Cave
# 7624                        Iron Mountain Out-and-Back    Glade Spring
# 9050                              Whetstone Ridge Ride  East Lexington
# 9018                    Potts Mountain Jeep Trail Loop      New Castle
# 9048                       Sherando Lake Advanced Loop      Nellysford
#
#              State  difficulty  length  ascent  descent  stars  latitude  \
# original  Colorado  Blue/Black    19.3    2655    -2660    3.6   39.6468
# 11319     Virginia  Blue/Black    18.0    2753    -2758    4.0   38.2866
# 7624      Virginia  Blue/Black    25.7    3717    -3719    4.0   36.6350
# 9050      Virginia       Black    26.2    3282    -3277    4.0   37.8193
# 9018      Virginia  Blue/Black    18.1    2475    -2472    3.0   37.6051
# 9048      Virginia       Black    19.2    3199    -3197    3.8   37.9265
#
#           longitude        ...          length_scaled ascent_scaled  \
# original  -105.1968        ...               2.008184      2.669567
# 11319      -79.3009        ...               1.843757      2.784162
# 7624       -81.7792        ...               2.817668      3.911406
# 9050       -79.2540        ...               2.880909      3.402743
# 9018       -80.0758        ...               1.856405      2.459085
# 9048       -78.9952        ...               1.995535      3.305688
#
#           descent_scaled  stars_scaled  latitude_scaled longitude_scaled  \
# original       -2.536204      0.383942         0.051045        -0.345581
# 11319          -2.646131      0.634053        -0.208535         1.116369
# 7624           -3.724096      0.634053        -0.523725         0.976456
# 9050           -3.228299      0.634053        -0.297714         1.119016
# 9018           -2.325322      0.008775        -0.338592         1.072622
# 9048           -3.138562      0.508998        -0.277256         1.133627
#
#           difficulty_encoded_scaled  type_Connector_scaled  \
# original                   0.909315              -0.485183
# 11319                      0.909315              -0.485183
# 7624                       0.909315              -0.485183
# 9050                       1.670197              -0.485183
# 9018                       0.909315              -0.485183
# 9048                       1.670197              -0.485183
#
#           type_Featured Ride_scaled  type_Trail_scaled
# original                   2.890924          -1.536982
# 11319                      2.890924          -1.536982
# 7624                       2.890924          -1.536982
# 9050                       2.890924          -1.536982
# 9018                       2.890924          -1.536982
# 9048                       2.890924          -1.536982
#
# [6 rows x 26 columns]

# %%
cos_sim_recommendations("The Whole Enchilada", 'Utah', Big_X, n = 15)
# Out:
#                                                    name           location  \
# original                            The Whole Enchilada               Moab
# 5653                          Cannell Trail - IMBA EPIC          Kernville
# 9939                            Never Eat Soggy Waffels           Junction
# 3294                          Bike For Bender Hell Ride      Big Bear City
# 11804                    Big Boulder from Packer Saddle        Downieville
# 10372                         Monarch Crest - IMBA EPIC          Whitepine
# 2188                                                CDO           Catalina
# 11800          Big Boulder from Butcher Ranch Trailhead        Downieville
# 9605           -5.156521      0.321414        -0.106340        -1.183659
# 18085          -6.105488      0.634053         0.822550        -1.252116
# 14036          -4.573231      0.946693         0.194708        -0.425820
# 12192          -4.482372      1.009221         0.035129        -0.406089
# 18211          -5.588380      1.259332         0.836729        -0.961345
# 11795          -4.988264      1.071749         0.044842        -1.218909
#
#           difficulty_encoded_scaled  type_Connector_scaled  \
# original                   1.670197              -0.485183
# 5653                       1.670197              -0.485183
# 9939                       1.670197              -0.485183
# 3294                       1.670197              -0.485183
# 11804                      1.670197              -0.485183
# 10372                      0.909315              -0.485183
# 2188                       1.670197              -0.485183
# 11800                      1.670197              -0.485183
# 1399                       2.431079              -0.485183
# 1522                       1.670197              -0.485183
# 9605                       1.670197              -0.485183
# 18085                      0.909315              -0.485183
# 14036                      0.909315              -0.485183
# 12192                      1.670197              -0.485183
# 18211                      0.909315              -0.485183
# 11795                      0.909315              -0.485183
#
#           type_Featured Ride_scaled  type_Trail_scaled
# original                   2.890924          -1.536982
# 5653                       2.890924          -1.536982
# 9939                       2.890924          -1.536982
# 3294                       2.890924          -1.536982
# 11804                      2.890924          -1.536982
# 10372                      2.890924          -1.536982
# 2188                       2.890924          -1.536982
# 11800                      2.890924          -1.536982
# 1399                       2.890924          -1.536982
# 1522                       2.890924          -1.536982
# 9605                       2.890924          -1.536982
# 18085                      2.890924          -1.536982
# 14036                      2.890924          -1.536982
# 12192                      2.890924          -1.536982
# 18211                      2.890924          -1.536982
# 11795                      2.890924          -1.536982
#
# [16 rows x 26 columns]

# %%
cos_sim_recommendations("Porcupine Rim", 'Utah', Big_X, n = 15, desired_state = 'Colorado', desired_location = 'Crested Butte')
# Out:
#                                                  name       location  \
# original                                Porcupine Rim           Moab
# 10271                                  401 Trail Loop  Crested Butte
# 10272                             Teocalli Ridge Loop  Crested Butte
# 10290                                 Dyke Trail Loop  Crested Butte
# 10293                                Green Lake Trail  Crested Butte
# 10287                     409s and Point Lookout Loop  Crested Butte
# 10284     Crystal Peak, Star Pass, Hunters Creek Loop  Crested Butte
# 10301                           Waterfall Cutoff Loop  Crested Butte
# 10273                  Reno/Flag/Bear/Deadman's Gulch  Crested Butte
# 10277             Snodgrass, Lupine, Lower Loop Combo  Crested Butte
# 10297                                 Deer Creek Loop  Crested Butte
# 10298                                Cliff Creek Loop  Crested Butte
# 10274                                     Strand Hill  Crested Butte
# 10275                                       Snodgrass  Crested Butte
# 10360                                 Pearl Pass Road  Crested Butte
# 10395                               Doctor Park Trail  Crested Butte
#
#              State    difficulty  length  ascent  descent  stars  latitude  \
# original      Utah         Black    14.7    1195    -2962    4.7   38.5819
# 10271     Colorado    Blue/Black    14.1    2249    -2222    4.6   38.9661
# 10272     Colorado    Blue/Black    11.5    2184    -2181    4.6   38.8969
# 10290     Colorado    Blue/Black    13.9    2265    -2270    3.8   38.8582
# 10293     Colorado         Black     8.4    1684    -1683    3.6   38.8671
